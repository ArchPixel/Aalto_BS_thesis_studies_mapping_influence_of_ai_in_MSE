# %%
# Import libraries
import numpy as np
# %pip install litstudy
import litstudy
import pickle
# Out:
# Requirement already satisfied: litstudy in f:\anaconda\lib\site-packages (1.0.6)
# Requirement already satisfied: bibtexparser in f:\anaconda\lib\site-packages (from litstudy) (1.4.4)
# Requirement already satisfied: gensim in f:\anaconda\lib\site-packages (from litstudy) (4.4.0)
# Requirement already satisfied: matplotlib in f:\anaconda\lib\site-packages (from litstudy) (3.10.6)
# Requirement already satisfied: networkx in f:\anaconda\lib\site-packages (from litstudy) (3.5)
# Requirement already satisfied: numpy in f:\anaconda\lib\site-packages (from litstudy) (2.3.5)
# Requirement already satisfied: pandas in f:\anaconda\lib\site-packages (from litstudy) (2.3.3)
# Requirement already satisfied: pybliometrics in f:\anaconda\lib\site-packages (from litstudy) (4.4.1)
# Requirement already satisfied: pyvis in f:\anaconda\lib\site-packages (from litstudy) (0.3.2)
# Requirement already satisfied: requests in f:\anaconda\lib\site-packages (from litstudy) (2.32.5)
# Requirement already satisfied: seaborn in f:\anaconda\lib\site-packages (from litstudy) (0.13.2)
# Requirement already satisfied: scikit-learn in f:\anaconda\lib\site-packages (from litstudy) (1.7.2)
# Requirement already satisfied: unidecode in f:\anaconda\lib\site-packages (from litstudy) (1.4.0)
# Requirement already satisfied: wordcloud in f:\anaconda\lib\site-packages (from litstudy) (1.9.6)
# Requirement already satisfied: feedparser in f:\anaconda\lib\site-packages (from litstudy) (6.0.12)
# Requirement already satisfied: pyparsing>=2.0.3 in f:\anaconda\lib\site-packages (from bibtexparser->litstudy) (3.2.5)
# Requirement already satisfied: sgmllib3k in f:\anaconda\lib\site-packages (from feedparser->litstudy) (1.0.0)
# Requirement already satisfied: scipy>=1.7.0 in f:\anaconda\lib\site-packages (from gensim->litstudy) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in f:\anaconda\lib\site-packages (from gensim->litstudy) (7.5.1)
# Requirement already satisfied: wrapt in f:\anaconda\lib\site-packages (from smart_open>=1.8.1->gensim->litstudy) (1.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in f:\anaconda\lib\site-packages (from matplotlib->litstudy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in f:\anaconda\lib\site-packages (from matplotlib->litstudy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in f:\anaconda\lib\site-packages (from matplotlib->litstudy) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in f:\anaconda\lib\site-packages (from matplotlib->litstudy) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in f:\anaconda\lib\site-packages (from matplotlib->litstudy) (25.0)
# Requirement already satisfied: pillow>=8 in f:\anaconda\lib\site-packages (from matplotlib->litstudy) (12.0.0)
# Requirement already satisfied: python-dateutil>=2.7 in f:\anaconda\lib\site-packages (from matplotlib->litstudy) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in f:\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib->litstudy) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in f:\anaconda\lib\site-packages (from pandas->litstudy) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in f:\anaconda\lib\site-packages (from pandas->litstudy) (2025.2)
# Requirement already satisfied: tqdm in f:\anaconda\lib\site-packages (from pybliometrics->litstudy) (4.67.1)
# Requirement already satisfied: urllib3 in f:\anaconda\lib\site-packages (from pybliometrics->litstudy) (2.5.0)
# Requirement already satisfied: ipython>=5.3.0 in f:\anaconda\lib\site-packages (from pyvis->litstudy) (9.7.0)
# Requirement already satisfied: jinja2>=2.9.6 in f:\anaconda\lib\site-packages (from pyvis->litstudy) (3.1.6)
# Requirement already satisfied: jsonpickle>=1.4.1 in f:\anaconda\lib\site-packages (from pyvis->litstudy) (4.1.1)
# Requirement already satisfied: colorama>=0.4.4 in f:\anaconda\lib\site-packages (from ipython>=5.3.0->pyvis->litstudy) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in f:\anaconda\lib\site-packages (from ipython>=5.3.0->pyvis->litstudy) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in f:\anaconda\lib\site-packages (from ipython>=5.3.0->pyvis->litstudy) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in f:\anaconda\lib\site-packages (from ipython>=5.3.0->pyvis->litstudy) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in f:\anaconda\lib\site-packages (from ipython>=5.3.0->pyvis->litstudy) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in f:\anaconda\lib\site-packages (from ipython>=5.3.0->pyvis->litstudy) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in f:\anaconda\lib\site-packages (from ipython>=5.3.0->pyvis->litstudy) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in f:\anaconda\lib\site-packages (from ipython>=5.3.0->pyvis->litstudy) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in f:\anaconda\lib\site-packages (from ipython>=5.3.0->pyvis->litstudy) (5.14.3)
# Requirement already satisfied: wcwidth in f:\anaconda\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis->litstudy) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in f:\anaconda\lib\site-packages (from jedi>=0.18.1->ipython>=5.3.0->pyvis->litstudy) (0.8.5)
# Requirement already satisfied: MarkupSafe>=2.0 in f:\anaconda\lib\site-packages (from jinja2>=2.9.6->pyvis->litstudy) (3.0.2)
# Requirement already satisfied: executing>=1.2.0 in f:\anaconda\lib\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->pyvis->litstudy) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in f:\anaconda\lib\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->pyvis->litstudy) (3.0.0)
# Requirement already satisfied: pure_eval in f:\anaconda\lib\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->pyvis->litstudy) (0.2.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in f:\anaconda\lib\site-packages (from requests->litstudy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in f:\anaconda\lib\site-packages (from requests->litstudy) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in f:\anaconda\lib\site-packages (from requests->litstudy) (2026.1.4)
# Requirement already satisfied: joblib>=1.2.0 in f:\anaconda\lib\site-packages (from scikit-learn->litstudy) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in f:\anaconda\lib\site-packages (from scikit-learn->litstudy) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# load the saved embedding file
docs_ai = []
with open('HEA_Docs_ai.pkl','rb') as f:
#with open('RAC_Docs_ai.pkl','rb') as f:
    docs_ai = pickle.load(f)

docs_nai = []
with open('HEA_Docs_nai.pkl','rb') as f:
#with open('RAC_Docs_nai.pkl','rb') as f:
    docs_nai = pickle.load(f)

print(docs_ai)
print(docs_nai)
# Out:
# <866 documents>
# <16758 documents>

# %%
import random
# make random samples 
ai_index = list(range(0,len(docs_ai)) )
nai_index = list(range(0,len(docs_nai)) )
random.shuffle(ai_index) # shuffled 
random.shuffle(nai_index)

ai_n = int(len(docs_ai)/10)
nai_n = int(len(docs_nai)/10)

ai_index_chunks = [ai_index[i:i+ai_n] for i in range(0,len(docs_ai),ai_n)]
nai_index_chunks = [nai_index[i:i+ai_n] for i in range(0,len(docs_ai),ai_n)]

ai_index_chunks = ai_index_chunks[:-1]
nai_index_chunks = nai_index_chunks[:-1]

# split docs into 10 samples each
docs_ai_samples = [docs_ai.select(t) for t in ai_index_chunks]
docs_nai_samples = [docs_nai.select(t) for t in nai_index_chunks]

print(docs_ai_samples)
print(docs_nai_samples)

print(docs_ai_samples[0][0].title)
print(docs_nai_samples[0][0].title)
# Out:
# [<86 documents>, <86 documents>, <86 documents>, <86 documents>, <86 documents>, <86 documents>, <86 documents>, <86 documents>, <86 documents>, <86 documents>]
# [<86 documents>, <86 documents>, <86 documents>, <86 documents>, <86 documents>, <86 documents>, <86 documents>, <86 documents>, <86 documents>, <86 documents>]
# Investigation of thermal transformation hysteresis of NiTiHf shape memory alloys via machine learning
# Enhancement of strength-ductility trade-off in a high-entropy alloy through a heterogeneous structure

# %%
import matplotlib.pyplot as plt
import seaborn as sbs

def gini_plot(docs_ai_samples,docs_nai_samples):

    plt.figure(figsize=(10, 10))
    y_all_ai = []
    y_all_nai = []

    for i in range(0,10):

        docs_ai = docs_ai_samples[i]
        docs_nai = docs_nai_samples[i]

        x= []
        y_ai =[]
        y_nai =[]

        citation_ai = []
        citation_nai = []

        for item in docs_ai:
            citation_ai.append(item.citation_count)

        for item in docs_nai:
            citation_nai.append(item.citation_count)

        x = np.array( range(1,len(docs_ai)+1 ) )
        x = (lambda x: x/max(x))(x)

        y_ai = np.sort(np.array(citation_ai))
        y_nai = np.sort(np.array(citation_nai))

        sum_ai = sum(y_ai)
        sum_nai = sum(y_nai)

        y_ai = [sum(y_ai[0:i+1])/sum_ai for i in range(0,len(y_ai)) ]
        y_nai = [sum(y_nai[0:i+1])/sum_nai for i in range(0,len(y_nai)) ]

        y_all_ai.append(y_ai)
        y_all_nai.append(y_nai)

        plt.plot(x,y_ai,color='yellow',alpha=0.4,linewidth=3)
        plt.plot(x,y_nai,color='skyblue',alpha=0.4,linewidth=3)
    
    y_aver_ai = []
    y_aver_nai = []

    for j in range(0,len(docs_ai_samples[0])):
        a_ai = 0
        a_nai = 0
        for k in range(0,10):
            a_ai += y_all_ai[k][j]
            a_nai += y_all_nai[k][j]
        y_aver_ai.append(a_ai/10)
        y_aver_nai.append(a_nai/10)

    x = np.array( range(1,len(docs_ai)+1 ) )
    x = (lambda x: x/max(x))(x)

    plt.plot(x,y_aver_ai,color='darkorange',label='HEA_ai_papers',alpha=1,linewidth=2)
    plt.plot(x,y_aver_nai,color='blue',label='HEA_non-ai_papers',alpha=1,linewidth=2)

    plt.axhline(y=0.5,xmin=0,xmax=0.923,linestyle='--',color='k',alpha=0.7)
    plt.axvline(x=0.898,ymin=0,ymax=0.5,linestyle='--',color='blue',alpha=0.7)
    plt.axvline(x=0.923,ymin=0,ymax=0.5,linestyle='--',color='darkorange',alpha=0.7)

    plt.title("Matthew effect in AI and Non-AI papers in HEA domain")
    plt.xlim(0,1)
    plt.ylim(0,1)
    plt.xticks(np.arange(0.0,1.1,0.1))
    plt.yticks(np.arange(0.0,1.1,0.1))
    plt.xlabel('Proportion of papers',fontsize=12)
    plt.ylabel('Proportion of citations',fontsize=12)

    plt.grid(True,alpha=0.5)
    plt.legend()
    plt.show()


gini_plot(docs_ai_samples,docs_nai_samples)

# %%
gini_ai_results = []
gini_nai_results = []

def gini_cal(docs_ai,docs_nai):
    citation_ai = []
    citation_nai = []

    for item in docs_ai:
        citation_ai.append(item.citation_count)

    for item in docs_nai:
        citation_nai.append(item.citation_count)

    x_ai = np.array( range(1,len(docs_ai)+1 ) )
    x_nai = np.array( range(1,len(docs_nai)+1) )

    y_ai = np.sort(np.array(citation_ai))
    y_nai = np.sort(np.array(citation_nai))

    size_ai = len(docs_ai)
    size_nai = len(docs_nai)

    gini_ai = ( 2*np.sum(np.multiply(x_ai,y_ai)) )/(size_ai*np.sum(y_ai)) - (size_ai+1)/size_ai
    gini_nai = ( 2*np.sum(np.multiply(x_nai,y_nai)) )/(size_nai*np.sum(y_nai)) - (size_nai+1)/size_nai

    print(gini_ai,":Gini Coefficient for HEA ai papers")
    print(gini_nai, ":Gini Coefficient for HEA non-ai papers")

    gini_ai_results.append(gini_ai)
    gini_nai_results.append(gini_nai)

for i in range(0,10):
    gini_cal(docs_ai_samples[i],docs_nai_samples[i])
# Out:
# 0.7020110560426991 :Gini Coefficient for HEA ai papers
# 0.7224819296040226 :Gini Coefficient for HEA non-ai papers
# 0.7277582254119415 :Gini Coefficient for HEA ai papers
# 0.6294267335830919 :Gini Coefficient for HEA non-ai papers
# 0.6980332447582287 :Gini Coefficient for HEA ai papers
# 0.6189168619786036 :Gini Coefficient for HEA non-ai papers
# 0.6710135827110104 :Gini Coefficient for HEA ai papers
# 0.6474539293506012 :Gini Coefficient for HEA non-ai papers
# 0.7570049306454303 :Gini Coefficient for HEA ai papers
# 0.634502698906005 :Gini Coefficient for HEA non-ai papers
# 0.7660470599524327 :Gini Coefficient for HEA ai papers
# 0.659499638510664 :Gini Coefficient for HEA non-ai papers
# 0.6576716664373194 :Gini Coefficient for HEA ai papers
# 0.6182170542635659 :Gini Coefficient for HEA non-ai papers
# 0.6946278984550094 :Gini Coefficient for HEA ai papers
# 0.54219157148175 :Gini Coefficient for HEA non-ai papers
# 0.7010752250234187 :Gini Coefficient for HEA ai papers
# 0.7368825957582372 :Gini Coefficient for HEA non-ai papers
# 0.6181365964234742 :Gini Coefficient for HEA ai papers
# 0.72227614288639 :Gini Coefficient for HEA non-ai papers

# %%
x = np.arange(1,11,1)
aver_ai = np.average(gini_ai_results)
aver_nai = np.average(gini_nai_results)
#median_ai = np.median(gini_ai_results)
#median_nai = np.median(gini_nai_results)
#print(median_ai)
#print(median_nai)
#print(aver_ai)
#print(aver_nai)

plt.figure(figsize=(20, 10))
plt.scatter(x,gini_ai_results,label='HEA_ai_gini',s=120,alpha=1,color='orange')
plt.scatter(x,gini_nai_results,label='HEA_nai_gini',s=120,alpha=1,color='blue')
plt.axhline(y=aver_ai,label='HEA_ai_gini_average',linestyle='--',color='orange')
#plt.axhline(y=median_ai,label='HEA_ai_gini_median',linestyle='-',color='orange')
plt.axhline(y=aver_nai,label='HEA_nai_gini_average',linestyle='--',color='blue')
#plt.axhline(y=median_nai,label='HEA_ai_gini_median',linestyle='-',color='blue')

min_e = np.subtract(gini_ai_results,-0.0015)
max_e = np.subtract(gini_nai_results,0.0015)
plt.vlines(x,ymin=min_e,ymax=max_e,colors='k',alpha=0.3)
plt.grid(True,alpha=0.5)

plt.xticks(x)
plt.yticks([min(gini_nai_results),aver_nai,aver_ai,max(gini_ai_results)])
plt.xlabel('Sample Number',fontsize=12)
plt.ylabel('Gini Coefficient',fontsize=12)
plt.title('Gini-coefficient for HEA domain', fontsize=14, fontweight='bold')

plt.legend()
plt.show()

# %%
# testing for citation metadata extract --- failed!!!
max_citation_ai = max(y_ai)
print(max_citation_ai, ": number of max citation in ai papers") 
top_ai = docs_ai.filter_docs(lambda d: d. citation_count == max_citation_ai)
print(top_ai[0].citations, ": list of documents that cite this document")
print(top_ai[0].title, ": title ")
print(top_ai[0].publication_year, ": publication year")

max_citation_nai = max(y_nai)
print(max_citation_nai, ": number of max citation in non-ai papers") 
top_nai = docs_nai.filter_docs(lambda d: d. citation_count == max_citation_nai)
print(top_nai[0].citations, ": list of documents that cite this document")
print(top_nai[0].title, ": title ")
print(top_nai[0].publication_year, ": publication year")
# Out:
# 766 : number of max citation in ai papers
# None : list of documents that cite this document
# Fatigue behavior of Al 0.5CoCrCuFeNi high entropy alloys : title
# 2012 : publication year
# 7718 : number of max citation in non-ai papers
# None : list of documents that cite this document
# A critical review of high entropy alloys and related concepts : title
# 2017 : publication year

# %%
x = np.array([1,2,3,4,5])
y = np.array([1,1,1,2,15])
gini = ( 2*np.sum(np.multiply(x,y)) )/(5*np.sum(y)) - 6/5
print(gini,":test")
# Out:
# 0.5800000000000001 :test
